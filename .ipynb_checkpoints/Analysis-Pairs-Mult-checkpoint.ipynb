# %%
import pandas as pd
import matplotlib.pyplot as plt
import importlib
import cointegration_mult as mult
import Cointegration as coint

importlib.reload(coint)
importlib.reload(mult)
# Out:
# <module 'cointegration_mult' from 'D:\\trades\\pairs_trading_b3\\cointegration_mult.py'>

# %%
path_data_cart = 'datasets/data_cart.csv'
path_data_yahoo = 'datasets/data_yahoo.csv'

# %%
data = pd.read_csv(path_data_cart, index_col=0)
data = data[::-1]
pairs = pd.read_csv('datasets/cointegrated_pairs_mult.csv')

print('{} to {}'.format(data.index[-1], data.index[0]))
print('data: {}'.format(data.shape))
print('pairs: {}'.format(pairs.shape))
# Out:
# 02/01/2019 to 07/07/2020
# data: (376, 71)
# pairs: (1897, 12)

# %%
pairs
# Out:
#       Period Dependent Independent  Dickey-Fuller  ADF      Beta  HalfLife  \
# 0        250     ABEV3       AZUL4       0.031658   95  0.117314         9
# 1        100     ABEV3       B3SA3       0.000085   99  0.228449         2
# 2        250     ABEV3       BBAS3       0.041324   95  0.222135        10
# 3        250     ABEV3       BBDC3       0.037843   95  0.341824        11
# 4        250     ABEV3       BBDC4       0.035837   95  0.350037        11
# ...      ...       ...         ...            ...  ...       ...       ...
# 1892     250     USIM5       WEGE3       0.017591   95  0.280947        11
# 1893     100     VALE3       VIVT4       0.026121   95  1.221917         5
# 1894     250     VALE3       VVAR3       0.027792   95  1.157682         9
# 1895     180     VIVT4       VVAR3       0.048437   90  0.648441         7
# 1896     240     VIVT4       WEGE3       0.024649   95  0.456191        10
#
#           Corr    Signal   SignalStr  PeriodQt  \
# 0     0.615632  1.172332  Short/Long         2
# 1     0.628667  0.108828  Long/Short         1
# 2     0.551361  0.885949  Short/Long         7
# 3     0.575381  0.946095  Short/Long         8
# 4     0.561564  0.830845  Short/Long         9
# ...        ...       ...         ...       ...
# 1892  0.456577  0.318768  Long/Short         6
# 1893  0.491082  0.116558  Long/Short         1
# 1894  0.537557  0.426913  Short/Long         5
# 1895  0.430804  0.405852  Long/Short         5
# 1896  0.346330  0.885246  Long/Short         8
#
#                                 PeriodStr
# 0                                 100,250
# 1                                     100
# 2             100,160,180,200,220,240,250
# 3         100,120,140,160,180,200,220,250
# 4     100,120,140,160,180,200,220,240,250
# ...                                   ...
# 1892              160,180,200,220,240,250
# 1893                                  100
# 1894                  100,200,220,240,250
# 1895                  100,120,140,160,180
# 1896      100,120,140,160,180,200,220,240
#
# [1897 rows x 12 columns]

# %%
pairs_signal = pairs.loc[(pairs['Signal'] >= 1) & (pairs['Signal'] <= 1.1)].copy()
pairs_signal.reset_index(drop=True, inplace=True)
pairs_signal.shape
# Out:
# (59, 12)

# %%
pairs_signal = pairs_signal.loc[(pairs_signal['PeriodQt'] >= 6) & (pairs_signal['ADF'] == 99)]\
.sort_values(by=['HalfLife'], ascending=True).copy()

pairs_signal.reset_index(drop=True, inplace=True)
pairs_signal
# Out:
#     Period Dependent Independent  Dickey-Fuller  ADF      Beta  HalfLife  \
# 0      250     ABEV3       CCRO3       0.000455   99  0.690821         5
# 1      220     GNDI3       MRVE3       0.001694   99  2.895195         5
# 2      250     ABEV3       BBSE3       0.001139   99  0.420276         6
# 3      250     ABEV3       HAPV3       0.001166   99  0.208012         6
# 4      250     RENT3      TAEE11       0.000654   99  3.846547         6
# 5      200     LAME4       MGLU3       0.006568   99  0.413097         6
# 6      250     ENBR3       RENT3       0.000784   99  0.258515         6
# 7      250     GOAU4       USIM5       0.006224   99  1.024013         7
# 8      250     GOAU4       MRVE3       0.003711   99  0.575945         7
# 9      250    ENGI11       MRVE3       0.004256   99  1.703847         7
# 10     250     CSAN3       MRVE3       0.003671   99  3.128127         7
# 11     250     CPFE3       VVAR3       0.003871   99  0.891955         7
# 12     250     CMIG4       CPFE3       0.001073   99  0.492736         7
# 13     250     GGBR4       MRVE3       0.005240   99  1.171997         7
# 14     250     UGPA3       USIM5       0.004400   99  2.301031         7
# 15     250     GGBR4       USIM5       0.008383   99  2.096541         8
# 16     250     TIMP3       WEGE3       0.008539   99  0.284715         8
# 17     250     CYRE3       ENBR3       0.008367   99  2.780160         8
#
#         Corr    Signal   SignalStr  PeriodQt  \
# 0   0.538201  1.052769  Short/Long         9
# 1   0.722136  1.034747  Long/Short         7
# 2   0.454599  1.066591  Short/Long         9
# 3   0.520273  1.012745  Short/Long         9
# 4   0.575320  1.078386  Short/Long         9
# 5   0.810991  1.019537  Long/Short         6
# 6   0.621771  1.011331  Long/Short         9
# 7   0.824486  1.018528  Long/Short         7
# 8   0.653967  1.062155  Long/Short         9
# 9   0.639156  1.003306  Long/Short         7
# 10  0.684797  1.028457  Long/Short         8
# 11  0.647547  1.069394  Long/Short         9
# 12  0.767343  1.042642  Short/Long         7
# 13  0.626442  1.054255  Long/Short         9
# 14  0.666820  1.016617  Long/Short         7
# 15  0.817901  1.035845  Long/Short         7
# 16  0.430269  1.055470  Long/Short         9
# 17  0.707191  1.062871  Short/Long         9
#
#                               PeriodStr
# 0   100,120,140,160,180,200,220,240,250
# 1           100,120,140,160,180,200,220
# 2   100,120,140,160,180,200,220,240,250
# 3   100,120,140,160,180,200,220,240,250
# 4   100,120,140,160,180,200,220,240,250
# 5               100,120,140,160,180,200
# 6   100,120,140,160,180,200,220,240,250
# 7           120,160,180,200,220,240,250
# 8   100,120,140,160,180,200,220,240,250
# 9           100,160,180,200,220,240,250
# 10      100,120,160,180,200,220,240,250
# 11  100,120,140,160,180,200,220,240,250
# 12          140,160,180,200,220,240,250
# 13  100,120,140,160,180,200,220,240,250
# 14          140,160,180,200,220,240,250
# 15          140,160,180,200,220,240,250
# 16  100,120,140,160,180,200,220,240,250
# 17  100,120,140,160,180,200,220,240,250

# %%
#pairs_signal.to_csv('datasets/sinais/sinais_06072020.csv', index=False)

# %%
oper = pairs_signal.loc[(pairs_signal['PeriodQt'] >= 9) & (pairs_signal['ADF'] >= 95) & (pairs_signal['HalfLife'] <= 6)]\
.sort_values(by=['HalfLife'], ascending=True).copy()
oper
# Out:
#    Period Dependent Independent  Dickey-Fuller  ADF      Beta  HalfLife  \
# 0     250     ABEV3       CCRO3       0.000455   99  0.690821         5
# 2     250     ABEV3       BBSE3       0.001139   99  0.420276         6
# 3     250     ABEV3       HAPV3       0.001166   99  0.208012         6
# 4     250     RENT3      TAEE11       0.000654   99  3.846547         6
# 6     250     ENBR3       RENT3       0.000784   99  0.258515         6
#
#        Corr    Signal   SignalStr  PeriodQt  \
# 0  0.538201  1.052769  Short/Long         9
# 2  0.454599  1.066591  Short/Long         9
# 3  0.520273  1.012745  Short/Long         9
# 4  0.575320  1.078386  Short/Long         9
# 6  0.621771  1.011331  Long/Short         9
#
#                              PeriodStr
# 0  100,120,140,160,180,200,220,240,250
# 2  100,120,140,160,180,200,220,240,250
# 3  100,120,140,160,180,200,220,240,250
# 4  100,120,140,160,180,200,220,240,250
# 6  100,120,140,160,180,200,220,240,250

# %%
#oper.iloc[[0,1,2]].to_csv('datasets/oper/06072020.csv', index=False)

# %% [markdown]
# # Análise das operações abertas

# %%
oper_current = pd.read_csv('datasets/oper/06072020.csv')
oper_current
# Out:
#    Period Dependent Independent  Dickey-Fuller  ADF      Beta  HalfLife  \
# 0     250    TAEE11       USIM5       0.000012   99  0.893375         4
# 1     250     CSAN3       FLRY3       0.000225   99  2.325672         5
# 2     250    ENGI11       VVAR3       0.000469   99  1.580477         5
#
#        Corr    Signal   SignalStr  PeriodQt  \
# 0  0.485344  1.091713  Long/Short         9
# 1  0.647742  1.093688  Short/Long         9
# 2  0.616080  1.057568  Long/Short         9
#
#                              PeriodStr
# 0  100,120,140,160,180,200,220,240,250
# 1  100,120,140,160,180,200,220,240,250
# 2  100,120,140,160,180,200,220,240,250

# %%
mult.plot_residue(mult.residue(data['TAEE11'], data['USIM5'], 250))

# %%
mult.plot_residue(mult.residue(data['ENGI11'], data['VVAR3'], 250))

# %%
mult.plot_residue(mult.residue(data['CSAN3'], data['FLRY3'], 250))

# %%
#coint.show(data[::-1], 'CSAN3', 'FLRY3')

# %%
mult.analysis_by_periods(data['SBSP3'], data['TAEE11'])
# Out:
#    Period  Stationary  Dickey-Fuller  ADF      Beta  HalfLife      Corr
# 0     100        True       0.010653   95  5.722677         3  0.621418
# 1     120        True       0.007307   99  5.449524         4  0.620175
# 2     140        True       0.019526   95  5.278662         5  0.608581
# 3     160        True       0.026219   95  4.542036         7  0.598616
# 4     180        True       0.015225   95  4.408481         7  0.593201
# 5     200        True       0.005870   99  4.462983         7  0.595282
# 6     220        True       0.004767   99  4.285034         7  0.588398
# 7     240        True       0.001914   99  4.246239         7  0.586822
# 8     250        True       0.001449   99  4.258682         7  0.585334

# %%
mult.dickey_fuller_ger(data['SBSP3'], data['TAEE11'], 250)
# Out:
# {'statistic': -3.046183111701164, 'adf': 0}
