# %% [markdown]
# https://www.youtube.com/watch?v=7GGrt3-rRH8
#
# https://pandas-datareader.readthedocs.io/en/latest/remote_data.html#

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
import pandas_datareader.data as web
yf.pdr_override()

# %%
ibov = web.get_data_yahoo(['^BVSP'])
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
ibov.head()
# Out:
#                  Open       High        Low      Close  Adj Close  Volume
# Date
# 1993-04-27  24.799999  25.400000  24.500000  24.500000  24.500000       0
# 1993-04-28  24.500000  24.600000  23.700001  24.299999  24.299999       0
# 1993-04-29  24.299999  24.799999  23.700001  23.700001  23.700001       0
# 1993-04-30  23.700001  24.200001  23.700001  24.100000  24.100000       0
# 1993-05-03  24.100000  24.400000  23.799999  24.100000  24.100000       0

# %%
ibov['Close'].plot(figsize=(22,8))

# %%
tickers = ['LREN3.SA', 'FLRY3.SA']

# %%
data = web.get_data_yahoo(tickers, start="2019-10-01")['Adj Close']
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
data
# Out:
#              FLRY3.SA   LREN3.SA
# Date
# 2019-10-01  25.485851  49.764572
# 2019-10-02  24.275030  47.813015
# 2019-10-03  24.411734  48.079136
# 2019-10-04  24.411734  48.256550
# 2019-10-07  23.630560  47.704605
# ...               ...        ...
# 2020-06-04  25.200001  44.560001
# 2020-06-05  25.790001  45.980000
# 2020-06-08  26.059999  46.209999
# 2020-06-09  25.590000  45.820000
# 2020-06-10  25.379999  43.900002
#
# [170 rows x 2 columns]

# %%
data.to_csv('datasets/yahoo.csv')
